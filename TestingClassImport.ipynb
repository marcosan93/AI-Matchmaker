# %% [markdown]
# # Importing the Class and Testing

# %%
# Importing our Class object from our .py file
from ProfileHandler import CreateProfile
import _pickle as pickle
import pandas as pd
pd.set_option('display.max_colwidth', 500)

# %%
# Importing the data to use
with open("Pickles/profiles.pkl",'rb') as fp:
    data = pickle.load(fp)

# %%
# Creating a new profile with the current dataset
new_profile = CreateProfile(dataset=data)

# %%
# Testing the manual input
new_profile.enter_info()
# Out:
#                                                                                                                  Bios  \
# 6600  Web nerd. Food evangelist. Award-winning social media lover. Coffee expert. Typical zombie specialist. Student.
#
#       Movies  TV  Religion  Music  Sports  Books  Politics
# 6600       8   7         3      9       5      0         3

# %%
# Running the methods
new_profile.add_profile_to_dataset()

new_profile.scale_profile()

new_profile.vect_text()

new_profile.format_profile()

# Displaying their results
display(new_profile.combined_df.tail(5))

display(new_profile.vectorized_text)

display(new_profile.scaled_profile)

display(new_profile.formatted_profile)
# Out:
#                                                                                                                  Bios  \
# 6596                       Avid web junkie. Lifelong alcohol guru. Hardcore reader. Award-winning twitter evangelist.
# 6597                            Music ninja. Bacon fanatic. Reader. Total communicator. Unapologetic beer specialist.
# 6598                                      Communicator. Bacon lover. Award-winning introvert. Amateur internet ninja.
# 6599                   Unapologetic tv aficionado. Devoted twitter enthusiast. Typical coffee guru. Falls down a lot.
# 6600  Web nerd. Food evangelist. Award-winning social media lover. Coffee expert. Typical zombie specialist. Student.
#
#       Movies  TV  Religion  Music  Sports  Books  Politics
# 6596       4   3         6      3       7      7         2
# 6597       1   4         0      4       9      2         5
# 6598       6   2         0      3       8      9         1
# ...
