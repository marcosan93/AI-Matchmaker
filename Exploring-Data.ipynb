# %% [markdown]
# # Exploring the User Profiles

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import _pickle as pickle

# %% [markdown]
# ### Loading the Data

# %%
with open("profiles.pkl",'rb') as fp:
    df = pickle.load(fp)

# %%
df
# Out:
#                                                   Bios  Movies  TV  Religion  \
# 0    Social media maven. Alcohol aficionado. Proud ...       9   6         4
# 1    Beer junkie. Student. Alcohol advocate. Reader...       6   1         7
# 2    Hipster-friendly web nerd. Internet ninja. Fre...       5   0         8
# 3    Social media guru. Total beer fanatic. Tv ninj...       3   2         2
# 4    Music practitioner. Amateur tv nerd. Evil inte...       0   2         8
# 5    Lifelong zombie ninja. Social media buff. Coff...       0   6         3
# 6    Friend of animals everywhere. Subtly charming ...       8   8         7
# 7    Extreme alcohol practitioner. Pop culture afic...       3   3         9
# 8    Travel fanatic. Lifelong organizer. Entreprene...       1   8         6
# 9    Unapologetic internet scholar. Alcohol enthusi...       3   0         1
# 10   Hardcore creator. Wannabe bacon ninja. Amateur...       4   1         5
# ...
