# %% [markdown]
# # Gathering Fake Data to Represent Dating Profiles
# Gathering random user bios and other profile data

# %% [markdown]
# ### Importing Libraries

# %%
import requests
import pandas as pd
import time
import random
import re
import numpy as np
import _pickle as pickle
from tqdm import tqdm_notebook as tqdm
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## BeautifulSoup to Navigate
# Getting the user bio data

# %%
# Randomizing the refresh rate
seq = [i/10 for i in range(8,18)]

# Creating a list of bios
biolist = []

# Gathering bios by looping and refreshing the web page
for _ in tqdm(range(1000)):
    
    # Refreshing the page
    page = requests.get("[insert website url here]")
    soup = bs(page.content)
    
    try:
        # Getting the bios
        bios = soup.find('div', class_='row no-margin for-sign').find_all('p')

        # Adding to a list of the bios
        biolist.extend([re.findall('"([^"]*)"', i.text) for i in bios])
    except:
        pass
    
    # Sleeping 
    time.sleep(random.choice(seq))
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
# Creating a DF from the bio list
bio_df = pd.DataFrame(biolist, columns=['Bios'])

# %% [markdown]
# ## Creating other Data

# %%
# List of potential Dating questions/categories
qs = ['Movies',
      'TV',
      'Religion',
      'Music',
      'Sports',
      'Books',
      'Politics']

# %%
# Creating a DF of the questions/categories
topic_df = pd.DataFrame(columns=qs)

# %%
# Filling in Data
for i in topic_df.columns:
    
    # Range of numbers to represent different labels in each category
    topic_df[i] = np.random.randint(0,10, bio_df.shape[0])
    
    # Logic: The numbers represent a specific choice within the categories
    # So your number 1 preferred artist/song/album under the Music, your one favorite movie, etc.

# %%
# Viewing the random data
topic_df
# Out:
#       Movies  TV  Religion  Music  Sports  Books  Politics
# 0          5   3         4      1       3      6         7
# 1          7   9         5      1       9      4         0
# 2          1   2         6      5       6      5         4
# 3          5   2         7      8       2      6         6
# 4          6   6         6      4       3      6         3
# 5          0   5         7      5       9      2         0
# 6          5   4         7      5       0      8         4
# 7          9   8         8      2       0      0         5
# 8          8   8         2      6       1      2         9
# 9          9   0         2      2       5      6         8
# 10         9   2         3      4       4      9         4
# 11         0   0         2      2       3      8         9
# 12         1   6         4      4       0      1         3
# 13         2   2         2      1       2      4         7
# 14         0   4         3      9       6      4         5
# 15         6   9         0      3       0      6         2
# 16         9   1         5      1       6      3         1
# 17         1   4         8      1       3      5         3
# 18         2   9         3      6       6      2         9
# 19         6   5         2      4       8      8         5
# 20         8   6         9      6       4      3         1
# 21         6   5         8      5       7      9         8
# 22         2   3         0      9       3      6         1
# 23         0   0         8      3       5      7         4
# 24         8   9         1      4       8      0         7
# 25         0   1         4      1       5      7         3
# 26         1   9         7      5       1      9         1
# 27         4   1         6      9       5      4         3
# 28         1   4         3      3       2      3         2
# 29         4   0         9      2       5      5         8
# ...      ...  ..       ...    ...     ...    ...       ...
# 6570       1   4         4      1       4      1         2
# 6571       3   1         7      6       4      6         8
# 6572       7   1         0      2       9      8         3
# 6573       9   1         6      2       2      6         6
# 6574       3   5         7      1       5      9         5
# 6575       1   6         8      8       1      0         1
# 6576       3   9         8      7       8      9         8
# 6577       7   2         6      3       4      2         3
# 6578       8   8         0      8       7      0         6
# 6579       5   8         0      1       4      1         8
# 6580       1   1         0      6       0      5         3
# 6581       4   0         2      2       0      8         1
# 6582       7   7         9      9       8      5         6
# 6583       0   4         8      7       5      4         9
# 6584       4   0         8      7       5      6         7
# 6585       2   2         6      5       4      4         7
# 6586       2   5         1      3       1      1         5
# 6587       2   8         4      5       1      2         2
# 6588       3   2         8      5       2      2         6
# 6589       9   2         3      8       2      7         4
# 6590       5   6         3      1       6      9         4
# 6591       6   7         3      5       6      3         7
# 6592       8   4         1      2       8      3         6
# 6593       9   7         7      6       3      4         4
# 6594       8   4         8      6       3      0         3
# 6595       7   9         0      0       2      2         4
# 6596       4   3         6      3       7      7         2
# 6597       1   4         0      4       9      2         5
# 6598       6   2         0      3       8      9         1
# 6599       2   1         8      7       0      5         5
#
# [6600 rows x 7 columns]

# %%
# Joining the two dataframes
final_df = bio_df.join(topic_df)
final_df
# Out:
#                                                    Bios  Movies  TV  Religion  \
# 0     Typical twitter fanatic. Infuriatingly humble ...       5   3         4
# 1     Web junkie. Analyst. Infuriatingly humble intr...       7   9         5
# 2     Avid web maven. Food practitioner. Gamer. Twit...       1   2         6
# 3     Twitteraholic. Extreme web fanatic. Food buff....       5   2         7
# 4     Bacon enthusiast. Falls down a lot. Freelance ...       6   6         6
# 5     Pop culture junkie. Tv buff. Reader. Friendly ...       0   5         7
# 6     Typical thinker. Amateur explorer. Reader. Ext...       5   4         7
# 7     Zombie maven. Travel geek. Professional social...       9   8         8
# 8     Lifelong introvert. General travel maven. Hips...       8   8         2
# 9     Travel ninja. Amateur pop culture evangelist. ...       9   0         2
# 10    Tv specialist. Professional coffee scholar. In...       9   2         3
# 11    Twitter guru. Food aficionado. Subtly charming...       0   0         2
# 12    Coffeeaholic. Entrepreneur. Explorer. Internet...       1   6         4
# 13    Pop culture trailblazer. Zombie nerd. Travel s...       2   2         2
# 14    Travel buff. Student. Alcohol trailblazer. Pas...       0   4         3
# 15    Avid pop culture fanatic. Social media enthusi...       6   9         0
# 16    Amateur alcohol practitioner. Food nerd. Proud...       9   1         5
# 17    Beer practitioner. Coffee expert. Tv guru. Soc...       1   4         8
# 18    Gamer. Twitter fan. Amateur entrepreneur. Writ...       2   9         3
# 19    Web guru. Extreme internet aficionado. Subtly ...       6   5         2
# 20    Zombie ninja. Extreme pop culture nerd. Infuri...       8   6         9
# 21    Entrepreneur. Friendly zombie aficionado. Orga...       6   5         8
# 22    Lifelong coffee expert. Friendly twitter pract...       2   3         0
# 23    Lifelong internet fanatic. Hardcore problem so...       0   0         8
# 24    Zombieaholic. Lifelong music junkie. Writer. D...       8   9         1
# 25    Bacon geek. Freelance food aficionado. Devoted...       0   1         4
# 26    Devoted alcohol geek. Problem solver. General ...       1   9         7
# 27    Gamer. Certified thinker. Reader. Music maven....       4   1         6
# 28    Lifelong coffee fanatic. Devoted travel enthus...       1   4         3
# 29    Amateur twitter expert. Certified travel nerd....       4   0         9
# ...                                                 ...     ...  ..       ...
# 6570  Communicator. Falls down a lot. Lifelong alcoh...       1   4         4
# 6571  Pop culture junkie. General thinker. Award-win...       3   1         7
# 6572  Music fanatic. Tv enthusiast. Professional bac...       7   1         0
# 6573  Hipster-friendly gamer. General bacon scholar....       9   1         6
# 6574  Creator. Music advocate. Extreme web fan. Food...       3   5         7
# 6575  Travel nerd. Extreme reader. Gamer. Tv advocat...       1   6         8
# 6576  Explorer. General entrepreneur. Infuriatingly ...       3   9         8
# 6577  Web aficionado. Pop culture lover. Subtly char...       7   2         6
# 6578  Devoted twitter aficionado. Music enthusiast. ...       8   8         0
# 6579  Beer fan. Troublemaker. Twitter evangelist. Tv...       5   8         0
# 6580  Beer fanatic. Coffee maven. Subtly charming mu...       1   1         0
# 6581  Professional zombie trailblazer. Extreme inter...       4   0         2
# 6582  Travel specialist. Unapologetic tv junkie. Ent...       7   7         9
# 6583  Student. Creator. Professional bacon enthusias...       0   4         8
# 6584  Total troublemaker. Bacon ninja. Hipster-frien...       4   0         8
# 6585  Friendly student. Zombie fan. Travel maven. Ex...       2   2         6
# 6586  Typical creator. Introvert. Pop culture enthus...       2   5         1
# 6587  Web scholar. Certified food fanatic. Internet ...       2   8         4
# 6588  Hardcore tv geek. Typical music buff. Hipster-...       3   2         8
# 6589  Pop culture maven. Coffee junkie. Friend of an...       9   2         3
# 6590  Unapologetic thinker. Certified beer trailblaz...       5   6         3
# 6591  Entrepreneur. Evil alcohol evangelist. Beer ma...       6   7         3
# 6592  Typical bacon lover. Professional food evangel...       8   4         1
# 6593  Reader. Music enthusiast. Tv junkie. Creator. ...       9   7         7
# 6594  Pop culture lover. Hardcore writer. Alcohol bu...       8   4         8
# 6595  Typical pop culture nerd. Infuriatingly humble...       7   9         0
# 6596  Avid web junkie. Lifelong alcohol guru. Hardco...       4   3         6
# 6597  Music ninja. Bacon fanatic. Reader. Total comm...       1   4         0
# 6598  Communicator. Bacon lover. Award-winning intro...       6   2         0
# 6599  Unapologetic tv aficionado. Devoted twitter en...       2   1         8
#
#       Music  Sports  Books  Politics
# 0         1       3      6         7
# 1         1       9      4         0
# 2         5       6      5         4
# 3         8       2      6         6
# 4         4       3      6         3
# 5         5       9      2         0
# 6         5       0      8         4
# 7         2       0      0         5
# 8         6       1      2         9
# 9         2       5      6         8
# 10        4       4      9         4
# 11        2       3      8         9
# 12        4       0      1         3
# 13        1       2      4         7
# 14        9       6      4         5
# 15        3       0      6         2
# 16        1       6      3         1
# 17        1       3      5         3
# 18        6       6      2         9
# 19        4       8      8         5
# 20        6       4      3         1
# 21        5       7      9         8
# 22        9       3      6         1
# 23        3       5      7         4
# 24        4       8      0         7
# 25        1       5      7         3
# 26        5       1      9         1
# 27        9       5      4         3
# 28        3       2      3         2
# 29        2       5      5         8
# ...     ...     ...    ...       ...
# 6570      1       4      1         2
# 6571      6       4      6         8
# 6572      2       9      8         3
# 6573      2       2      6         6
# 6574      1       5      9         5
# 6575      8       1      0         1
# 6576      7       8      9         8
# 6577      3       4      2         3
# 6578      8       7      0         6
# 6579      1       4      1         8
# 6580      6       0      5         3
# 6581      2       0      8         1
# 6582      9       8      5         6
# 6583      7       5      4         9
# 6584      7       5      6         7
# 6585      5       4      4         7
# 6586      3       1      1         5
# 6587      5       1      2         2
# 6588      5       2      2         6
# 6589      8       2      7         4
# 6590      1       6      9         4
# 6591      5       6      3         7
# 6592      2       8      3         6
# 6593      6       3      4         4
# 6594      6       3      0         3
# 6595      0       2      2         4
# 6596      3       7      7         2
# 6597      4       9      2         5
# 6598      3       8      9         1
# 6599      7       0      5         5
#
# [6600 rows x 8 columns]

# %% [markdown]
# ## Exporting the DF of Random User data

# %%
with open("profiles.pkl", "wb") as fp:
    pickle.dump(final_df, fp)
