# %% [markdown]
# # Refining Profile Data
# Adding information to the categories

# %% [markdown]
# ### Library and Data Imports

# %%
import pandas as pd
import _pickle as pickle
import numpy as np
from scipy.stats import halfnorm

# %%
with open("profiles.pkl",'rb') as fp:
    df = pickle.load(fp)

# %%
# Removing the numerical data
df = df[['Bios']]

# %% [markdown]
# ### Creating Lists for the Categories

# %%
# Probability dictionary
p = {}

# Movie Genres
movies = ['Adventure',
          'Action',
          'Drama',
          'Comedy',
          'Thriller',
          'Horror',
          'RomCom',
          'Musical',
          'Documentary']

p['Movies'] = [0.28,
               0.21,
               0.16,
               0.14,
               0.09,
               0.06,
               0.04,
               0.01, 
               0.01]

# TV Genres
tv = ['Comedy',
      'Drama',
      'Action/Adventure',
      'Suspense/Thriller',
      'Documentaries',
      'Crime/Mystery',
      'News',
      'SciFi',
      'History']

p['TV'] = [0.30,
           0.23,
           0.12,
           0.12,
           0.09,
           0.08,
           0.03,
           0.02,
           0.01]

# Religions (could potentially create a spectrum)
religion = ['Catholic',
            'Christian',
            'Jewish',
            'Muslim',
            'Hindu',
            'Buddhist',
            'Spiritual',
            'Other',
            'Agnostic',
            'Atheist']

p['Religion'] = [0.16,
                 0.16,
                 0.01,
                 0.19,
                 0.11,
                 0.05,
                 0.10,
                 0.09,
                 0.07,
                 0.06]

# Music
music = ['Rock',
         'HipHop',
         'Pop',
         'Country',
         'Latin',
         'EDM',
         'Gospel',
         'Jazz',
         'Classical']

p['Music'] = [0.30,
              0.23,
              0.20,
              0.10,
              0.06,
              0.04,
              0.03,
              0.02,
              0.02]

# Sports
sports = ['Football',
          'Baseball',
          'Basketball',
          'Hockey',
          'Soccer',
          'Other']

p['Sports'] = [0.34,
               0.30,
               0.16, 
               0.13,
               0.04,
               0.03]

# Politics (could also put on a spectrum)
politics = ['Liberal',
            'Progressive',
            'Centrist',
            'Moderate',
            'Conservative']

p['Politics'] = [0.26,
                 0.11,
                 0.11,
                 0.15,
                 0.37]

# Social Media
social = ['Facebook',
          'Youtube',
          'Twitter',
          'Reddit',
          'Instagram',
          'Pinterest',
          'LinkedIn',
          'SnapChat',
          'TikTok']

p['Social Media'] = [0.36,
                     0.27,
                     0.11,
                     0.09,
                     0.05,
                     0.03,
                     0.03,
                     0.03,
                     0.03]

# Age (generating random numbers based on half normal distribution)
age = halfnorm.rvs(loc=18,scale=8, size=df.shape[0]).astype(int)

# Lists of Names and the list of the lists
categories = [movies, religion, music, politics, social, sports, age]

names = ['Movies','Religion', 'Music', 'Politics', 'Social Media', 'Sports', 'Age']

combined = dict(zip(names, categories))

# %% [markdown]
# ### Establishing random values for each category

# %%
# Looping through and assigning random values
for name, cats in combined.items():
    if name in ['Religion', 'Politics']:
        # Picking only 1 from the list
        df[name] = np.random.choice(cats, df.shape[0], p=p[name])
        
    elif name == 'Age':
        # Generating random ages based on a normal distribution
        df[name] = cats
    else:
        # Picking 3 from the list 
        try:
            df[name] = list(np.random.choice(cats, size=(df.shape[0],1,3), p=p[name]))
        except:
            df[name] = list(np.random.choice(cats, size=(df.shape[0],1,3)))
        
        df[name] = df[name].apply(lambda x: list(set(x[0].tolist())))

# %%
df
# Out:
#                                                    Bios  \
# 0     Typical twitter fanatic. Infuriatingly humble ...
# 1     Web junkie. Analyst. Infuriatingly humble intr...
# 1                   [Comedy, Drama]  Spiritual                 [HipHop, Pop]
# 2                  [Horror, Comedy]  Christian                [HipHop, Rock]
# 3               [Adventure, Comedy]   Agnostic                        [Rock]
# 4        [Action, Adventure, Drama]      Hindu         [Latin, Rock, HipHop]
# 5        [Adventure, Comedy, Drama]      Hindu                   [Pop, Rock]
# 6        [Action, Adventure, Drama]      Other                   [Pop, Rock]
# 7         [Action, Thriller, Drama]  Spiritual                   [Pop, Rock]
# 8     [Action, Comedy, Documentary]      Hindu         [Latin, Rock, HipHop]
# 9                   [Comedy, Drama]      Hindu           [Country, Pop, EDM]
# 10       [Action, Adventure, Drama]  Spiritual          [Latin, HipHop, Pop]
# 11                 [Horror, Action]   Agnostic                   [Pop, Rock]
# 12                      [Adventure]   Catholic         [Country, Latin, EDM]
# 13              [Adventure, Comedy]  Christian                [HipHop, Rock]
# 14              [Adventure, Comedy]   Buddhist           [EDM, HipHop, Rock]
# 15            [Thriller, Adventure]      Hindu         [Gospel, Pop, HipHop]
# 16                [Thriller, Drama]     Muslim               [Country, Rock]
# 17    [Thriller, Adventure, Horror]  Christian           [Pop, Rock, HipHop]
# 18                          [Drama]  Christian           [HipHop, Rock, Pop]
# 19      [Action, Adventure, Comedy]     Muslim                 [Pop, HipHop]
# 20       [Action, Thriller, Horror]   Buddhist  [Country, HipHop, Classical]
# 21      [Adventure, RomCom, Comedy]  Christian                   [Pop, Rock]
# 22    [Thriller, Adventure, Action]      Hindu                 [Latin, Rock]
# 23        [Thriller, Comedy, Drama]   Agnostic       [Country, HipHop, Rock]
# 24         [Horror, Comedy, Action]     Muslim                        [Rock]
# 25                  [Comedy, Drama]    Atheist                [HipHop, Rock]
# 26       [Adventure, Comedy, Drama]      Hindu                   [Pop, Rock]
# 27                  [Action, Drama]     Muslim         [Latin, Rock, HipHop]
# 28            [Thriller, Adventure]    Atheist        [Gospel, HipHop, Rock]
# 29    [Thriller, Adventure, Comedy]     Muslim                   [Pop, Rock]
# ...                             ...        ...                           ...
# 6570                [Action, Drama]    Atheist             [Country, HipHop]
# 6571             [Adventure, Drama]   Catholic           [HipHop, Rock, Pop]
# 6572    [Horror, Adventure, Comedy]      Other                   [Pop, Rock]
# 6573    [Action, Adventure, Comedy]  Spiritual                 [HipHop, Pop]
# 6574    [Action, Adventure, Horror]   Buddhist               [Latin, HipHop]
# 6575     [Adventure, Comedy, Drama]      Hindu           [EDM, HipHop, Rock]
# 6576     [Adventure, Comedy, Drama]  Spiritual           [Pop, Rock, HipHop]
# 6577            [Action, Adventure]  Christian           [EDM, HipHop, Rock]
# 6578    [Action, Adventure, Comedy]    Atheist               [Latin, HipHop]
# 6579                [Action, Drama]  Christian                [HipHop, Rock]
# 6580        [Action, Comedy, Drama]  Spiritual                [Country, Pop]
# 6581            [Adventure, RomCom]   Agnostic           [HipHop, Rock, Pop]
# 6582            [Action, Adventure]      Hindu           [Pop, Rock, HipHop]
# 6583             [Adventure, Drama]     Muslim               [Country, Rock]
# 6584              [Thriller, Drama]   Agnostic                [HipHop, Rock]
# 6585                [Action, Drama]  Christian                [HipHop, Rock]
# 6586     [Action, Adventure, Drama]  Christian     [Country, Gospel, HipHop]
# 6587     [Adventure, RomCom, Drama]  Spiritual               [Country, Rock]
# 6588     [Action, Adventure, Drama]  Spiritual          [Latin, Pop, HipHop]
# 6589                [Action, Drama]     Muslim              [EDM, Pop, Rock]
# 6590     [Adventure, RomCom, Drama]  Spiritual               [Country, Rock]
# 6591    [Action, Adventure, Comedy]  Christian                      [HipHop]
# 6592               [Action, Comedy]    Atheist             [Country, HipHop]
# 6593     [Action, Adventure, Drama]      Hindu         [Country, Rock, Jazz]
# 6594     [Action, Adventure, Drama]     Muslim                 [HipHop, EDM]
# 6595     [Thriller, Comedy, Action]   Catholic           [Pop, Rock, HipHop]
# 6596               [Action, Horror]  Spiritual             [Rock, Classical]
# 6597             [Adventure, Drama]   Catholic             [Country, HipHop]
# 6598             [Adventure, Drama]  Christian          [Country, Pop, Rock]
# 6599     [Adventure, RomCom, Drama]   Catholic                   [Pop, Rock]
#
#           Politics                     Social Media  \
# 0      Progressive     [Twitter, Reddit, Instagram]
# 1     Conservative              [Twitter, Facebook]
# 2         Moderate                [Reddit, Youtube]
# 3         Moderate              [Facebook, Youtube]
# 4     Conservative       [Twitter, TikTok, Youtube]
# 5          Liberal             [Instagram, Youtube]
# 6          Liberal    [Pinterest, Twitter, Youtube]
# 7          Liberal                 [Reddit, TikTok]
# 8     Conservative                       [Facebook]
# 9     Conservative                         [Reddit]
# 10        Moderate      [Facebook, TikTok, Youtube]
# 11    Conservative      [Facebook, Reddit, Youtube]
# 12    Conservative             [LinkedIn, Facebook]
# 13    Conservative      [Facebook, Reddit, Youtube]
# 14     Progressive              [Facebook, Youtube]
# 15         Liberal      [Facebook, TikTok, Youtube]
# 16         Liberal              [Facebook, Youtube]
# 17         Liberal     [Twitter, Reddit, Instagram]
# 18        Moderate              [Facebook, Youtube]
# 19    Conservative             [Facebook, SnapChat]
# 20        Moderate  [Pinterest, Facebook, SnapChat]
# 21     Progressive        [Reddit, TikTok, Youtube]
# 22        Moderate              [Facebook, Youtube]
# 23         Liberal              [LinkedIn, Youtube]
# 24         Liberal   [Pinterest, Reddit, Instagram]
# 25    Conservative    [Twitter, Facebook, SnapChat]
# 26     Progressive               [Facebook, Reddit]
# 27        Centrist              [Facebook, Youtube]
# 28        Moderate              [Twitter, Facebook]
# 29    Conservative              [Instagram, TikTok]
# ...            ...                              ...
# 6570       Liberal     [Facebook, SnapChat, TikTok]
# 6571  Conservative               [Facebook, Reddit]
# 6572      Centrist              [Facebook, Youtube]
# 6573      Centrist      [Facebook, Reddit, Youtube]
# 6574       Liberal               [Facebook, Reddit]
# 6575  Conservative     [Twitter, Facebook, Youtube]
# 6576  Conservative                [Reddit, Youtube]
# 6577       Liberal            [Facebook, Instagram]
# 6578      Centrist             [LinkedIn, Facebook]
# 6579      Moderate    [Twitter, Instagram, Youtube]
# 6580      Centrist      [Facebook, Reddit, Youtube]
# 6581  Conservative               [Facebook, Reddit]
# 6582  Conservative              [Facebook, Youtube]
# 6583       Liberal     [Twitter, Facebook, Youtube]
# 6584       Liberal    [Facebook, Instagram, TikTok]
# 6585       Liberal     [Twitter, Facebook, Youtube]
# 6586       Liberal              [Twitter, Facebook]
# 6587       Liberal              [Twitter, Facebook]
# 6588  Conservative    [Facebook, SnapChat, Youtube]
# 6589  Conservative     [Twitter, Facebook, Youtube]
# 6590      Moderate              [Facebook, Youtube]
# 6591  Conservative              [Facebook, Youtube]
# 6592  Conservative      [Facebook, Reddit, Youtube]
# 6593      Moderate  [Pinterest, Facebook, SnapChat]
# 6594       Liberal    [Facebook, Reddit, Instagram]
# 6595       Liberal      [Facebook, Reddit, Youtube]
# 6596  Conservative   [Facebook, Instagram, Youtube]
# 6597   Progressive              [Facebook, Youtube]
# 6598      Moderate    [Pinterest, Facebook, Reddit]
# 6599  Conservative               [Twitter, Youtube]
#
#                                 Sports  Age
# 0       [Basketball, Football, Hockey]   19
# 1         [Basketball, Soccer, Hockey]   19
# 2                 [Baseball, Football]   21
# 3       [Basketball, Football, Hockey]   25
# 4       [Hockey, Football, Basketball]   19
# 5                 [Baseball, Football]   23
# 6                 [Baseball, Football]   20
# 7                     [Soccer, Hockey]   22
# 8                           [Baseball]   19
# 9       [Hockey, Football, Basketball]   29
# 10                [Baseball, Football]   22
# 11                          [Baseball]   19
# 12        [Soccer, Baseball, Football]   23
# 13                  [Hockey, Football]   32
# 14        [Hockey, Baseball, Football]   34
# 15                [Baseball, Football]   26
# 16    [Football, Baseball, Basketball]   24
# 17                  [Football, Hockey]   27
# 18        [Football, Baseball, Hockey]   23
# 19                [Baseball, Football]   27
# 20          [Soccer, Baseball, Hockey]   22
# 21              [Baseball, Basketball]   25
# 22        [Soccer, Baseball, Football]   24
# 23                [Baseball, Football]   18
# 24                [Baseball, Football]   26
# 25              [Baseball, Basketball]   21
# 26              [Football, Basketball]   25
# 27              [Basketball, Football]   24
# 28                          [Football]   28
# 29                [Baseball, Football]   28
# ...                                ...  ...
# 6570              [Baseball, Football]   23
# 6571                [Soccer, Baseball]   24
# 6572    [Basketball, Soccer, Football]   23
# 6573       [Other, Baseball, Football]   19
# 6574              [Baseball, Football]   19
# 6575              [Baseball, Football]   24
# 6576    [Hockey, Football, Basketball]   24
# 6577            [Baseball, Basketball]   21
# 6578    [Soccer, Baseball, Basketball]   23
# 6579    [Basketball, Baseball, Hockey]   24
# 6580  [Basketball, Baseball, Football]   26
# 6581              [Baseball, Football]   22
# 6582    [Hockey, Basketball, Football]   28
# 6583      [Soccer, Baseball, Football]   23
# 6584    [Hockey, Basketball, Football]   19
# 6585  [Football, Baseball, Basketball]   21
# 6586              [Baseball, Football]   30
# 6587              [Baseball, Football]   18
# 6588                [Soccer, Football]   22
# 6589              [Baseball, Football]   24
# 6590              [Baseball, Football]   25
# 6591            [Football, Basketball]   29
# 6592              [Baseball, Football]   20
# 6593              [Baseball, Football]   24
# 6594    [Basketball, Baseball, Hockey]   20
# 6595                        [Baseball]   28
# 6596                [Baseball, Hockey]   24
# 6597            [Football, Basketball]   24
# 6598              [Baseball, Football]   20
# 6599                [Baseball, Hockey]   19
#
# [6600 rows x 8 columns]

# %% [markdown]
# ### Categorizing

# %%
df['Religion'] = pd.Categorical(df.Religion, ordered=True,
                                categories=['Catholic',
                                            'Christian',
                                            'Jewish',
                                            'Muslim',
                                            'Hindu',
                                            'Buddhist',
                                            'Spiritual',
                                            'Other',
                                            'Agnostic',
                                            'Atheist'])

df['Politics'] = pd.Categorical(df.Politics, ordered=True,
                                categories=['Liberal',
                                            'Progressive',
                                            'Centrist',
                                            'Moderate',
                                            'Conservative'])

# %% [markdown]
# ### Exporting the DF

# %%
with open("refined_profiles.pkl",'wb') as fp:
    pickle.dump(df, fp)
