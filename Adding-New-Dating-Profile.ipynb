# %% [markdown]
# # Adding a New Dating Profile
# Using Classification or Clustering for a New Dating Profile

# %% [markdown]
# ### Importing Libraries and Data

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 500)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import _pickle as pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import calinski_harabaz_score, silhouette_score, davies_bouldin_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.pipeline import Pipeline
from tqdm import tqdm_notebook as tqdm

# %% [markdown]
# #### Loading the Profiles

# %%
# Loading in the cleaned DF
with open("profiles.pkl",'rb') as fp:
    raw_df = pickle.load(fp)

# Viewing the DF    
raw_df.head()
# Out:
#                                                                                                     Bios  \
# 0        Typical twitter fanatic. Infuriatingly humble thinker. Lifelong coffee practitioner. Organizer.
# 1  Web junkie. Analyst. Infuriatingly humble introvert. Food nerd. Lifelong music fanatic. Coffee lover.
# 2     Avid web maven. Food practitioner. Gamer. Twitter fanatic. Pop culture scholar. Zombie evangelist.
# 3                      Twitteraholic. Extreme web fanatic. Food buff. Infuriatingly humble entrepreneur.
# 4        Bacon enthusiast. Falls down a lot. Freelance social media fan. Infuriatingly humble introvert.
#
#    Movies  TV  Religion  Music  Sports  Books  Politics
# 0       5   3         4      1       3      6         7
# 1       7   9         5      1       9      4         0
# 2       1   2         6      5       6      5         4
# 3       5   2         7      8       2      6         6
# 4       6   6         6      4       3      6         3

# %% [markdown]
# #### Loading the Clustered Profiles

# %%
# Loading in the clustered DF
with open("clustered_profiles.pkl",'rb') as fp:
    cluster_df = pickle.load(fp)

# Viewing the DF    
cluster_df.head()
# Out:
#                                                                                                     Bios  \
# 0        Typical twitter fanatic. Infuriatingly humble thinker. Lifelong coffee practitioner. Organizer.
# 1  Web junkie. Analyst. Infuriatingly humble introvert. Food nerd. Lifelong music fanatic. Coffee lover.
# 2     Avid web maven. Food practitioner. Gamer. Twitter fanatic. Pop culture scholar. Zombie evangelist.
# 3                      Twitteraholic. Extreme web fanatic. Food buff. Infuriatingly humble entrepreneur.
# 4        Bacon enthusiast. Falls down a lot. Freelance social media fan. Infuriatingly humble introvert.
#
#    Movies   TV  Religion  Music  Sports  Books  Politics  Cluster #
# 0     5.0  3.0       4.0    1.0     3.0    6.0       7.0          9
# 1     7.0  9.0       5.0    1.0     9.0    4.0       0.0          9
# 2     1.0  2.0       6.0    5.0     6.0    5.0       4.0          1
# 3     5.0  2.0       7.0    8.0     2.0    6.0       6.0          9
# 4     6.0  6.0       6.0    4.0     3.0    6.0       3.0         10

# %% [markdown]
# ## Creating the New Profile Data

# %%
# Instantiating a new DF row to append later
new_profile = pd.DataFrame(columns=raw_df.columns)

# Adding random values for new data
for i in new_profile.columns[1:]:
    new_profile[i] = np.random.randint(0,10,1)

# Printing an user interface for inputting new values
print("Enter new profile information...\n\nExample Bio:\nBacon enthusiast. Falls down a lot. Freelance social media fan. Infuriatingly humble introvert.")

# Asking for new profile data
new_profile['Bios'] = input("Enter a Bio for yourself: ")

# Indexing that new profile data
new_profile.index = [raw_df.index[-1] + 1]
# Out:
# Enter new profile information...
#
# Example Bio:
# Bacon enthusiast. Falls down a lot. Freelance social media fan. Infuriatingly humble introvert.
# Enter a Bio for yourself: food lover. social media fanatic. extraordinarily humble. life lover.

# %% [markdown]
# ### The New Data

# %%
new_profile
# Out:
#                                                                        Bios  \
# 6600  food lover. social media fanatic. extraordinarily humble. life lover.
#
#       Movies  TV  Religion  Music  Sports  Books  Politics
# 6600       4   9         3      6       6      0         3

# %% [markdown]
# # Two Approaches
# 1. Cluster all the profiles again with the new profile
#
# 2. Classify the new profile with a classification model trained on our previously clustered data

# %% [markdown]
# ## Clustering the New Profile Data

# %%
# Appending the new data
new_cluster = raw_df.append(new_profile)
# Out:
#                                                                                                 Bios  \
# 6596      Avid web junkie. Lifelong alcohol guru. Hardcore reader. Award-winning twitter evangelist.
# 6597           Music ninja. Bacon fanatic. Reader. Total communicator. Unapologetic beer specialist.
# 6598                     Communicator. Bacon lover. Award-winning introvert. Amateur internet ninja.
# 6599  Unapologetic tv aficionado. Devoted twitter enthusiast. Typical coffee guru. Falls down a lot.
# 6600                           food lover. social media fanatic. extraordinarily humble. life lover.
#
#       Movies  TV  Religion  Music  Sports  Books  Politics
# 6596       4   3         6      3       7      7         2
# 6597       1   4         0      4       9      2         5
# 6598       6   2         0      3       8      9         1
# 6599       2   1         8      7       0      5         5
# 6600       4   9         3      6       6      0         3

# %% [markdown]
# ### Scaling

# %%
# Instantiating the Scaler
scaler = MinMaxScaler()

# Scaling the categories then replacing the old values
df = new_cluster[['Bios']].join(pd.DataFrame(scaler.fit_transform(new_cluster.drop('Bios', axis=1)), columns=new_cluster.columns[1:], index=new_cluster.index))
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#                                                                                                                                                        Bios  \
# 0                                                           Typical twitter fanatic. Infuriatingly humble thinker. Lifelong coffee practitioner. Organizer.
# 1                                                     Web junkie. Analyst. Infuriatingly humble introvert. Food nerd. Lifelong music fanatic. Coffee lover.
# 2                                                        Avid web maven. Food practitioner. Gamer. Twitter fanatic. Pop culture scholar. Zombie evangelist.
# 3                                                                         Twitteraholic. Extreme web fanatic. Food buff. Infuriatingly humble entrepreneur.
# 4                                                           Bacon enthusiast. Falls down a lot. Freelance social media fan. Infuriatingly humble introvert.
# 5         Pop culture junkie. Tv buff. Reader. Friendly travel expert. Incurable twitteraholic. Social media ninja. Coffee enthusiast. Internet specialist.
# 6                                                               Typical thinker. Amateur explorer. Reader. Extreme student. Tv fanatic. Social media ninja.
# 7                                                                        Zombie maven. Travel geek. Professional social media buff. Avid pop culture lover.
# 8                      Lifelong introvert. General travel maven. Hipster-friendly web trailblazer. Writer. Alcohol fan. Student. Communicator. Coffee guru.
# 9                                                           Travel ninja. Amateur pop culture evangelist. Web fanatic. Freelance communicator. Zombie geek.
# 10                                                                Tv specialist. Professional coffee scholar. Introvert. Thinker. Creator. Travel advocate.
# 11    Twitter guru. Food aficionado. Subtly charming coffee ninja. Incurable web practitioner. Travel evangelist. Hardcore music nerd. Devoted bacon maven.
# 12                                                                  Coffeeaholic. Entrepreneur. Explorer. Internet maven. Twitter evangelist. Alcohol geek.
# 13                                                        Pop culture trailblazer. Zombie nerd. Travel specialist. Foodaholic. Total student. Twitter buff.
# 14                                                Travel buff. Student. Alcohol trailblazer. Passionate social media ninja. Entrepreneur. Incurable writer.
# 15                                                       Avid pop culture fanatic. Social media enthusiast. Incurable introvert. Typical web maven. Reader.
# 16                                              Amateur alcohol practitioner. Food nerd. Proud analyst. Beer guru. Award-winning coffee fanatic. Organizer.
# 17                                            Beer practitioner. Coffee expert. Tv guru. Social media junkie. Bacon enthusiast. General student. Food nerd.
# 18                                      Gamer. Twitter fan. Amateur entrepreneur. Writer. Falls down a lot. Passionate music enthusiast. Freelance analyst.
# 19               Web guru. Extreme internet aficionado. Subtly charming travel maven. Food nerd. Friend of animals everywhere. Devoted pop culture fanatic.
# 20                                        Zombie ninja. Extreme pop culture nerd. Infuriatingly humble alcohol fanatic. Music junkie. Professional analyst.
# 21                                    Entrepreneur. Friendly zombie aficionado. Organizer. Passionate coffee geek. Avid introvert. Pop culture trailblazer.
# 22                                   Lifelong coffee expert. Friendly twitter practitioner. General internet geek. Food nerd. Pop culture fanatic. Thinker.
# 23                                           Lifelong internet fanatic. Hardcore problem solver. Total entrepreneur. Extreme food geek. Twitter aficionado.
# 24                                          Zombieaholic. Lifelong music junkie. Writer. Devoted communicator. General pop culture fan. Unapologetic gamer.
# 25                              Bacon geek. Freelance food aficionado. Devoted internet fanatic. Explorer. Friendly music trailblazer. Incurable beer buff.
# 26                                      Devoted alcohol geek. Problem solver. General analyst. Award-winning bacon specialist. Friendly twitter aficionado.
# 27                       Gamer. Certified thinker. Reader. Music maven. Total social media geek. Introvert. Typical problem solver. Award-winning explorer.
# 28                                                                             Lifelong coffee fanatic. Devoted travel enthusiast. Introvert. Troublemaker.
# 29                                                             Amateur twitter expert. Certified travel nerd. Music buff. Proud zombie geek. Beer advocate.
# ...                                                                                                                                                     ...
# 6571                                                                      Pop culture junkie. General thinker. Award-winning food evangelist. Troublemaker.
# 6572                                                         Music fanatic. Tv enthusiast. Professional bacon aficionado. Explorer. Subtly charming writer.
# 6573                                Hipster-friendly gamer. General bacon scholar. Subtly charming social media lover. Proud explorer. Alcohol trailblazer.
# 6574                                                                       Creator. Music advocate. Extreme web fan. Food scholar. Passionate travel ninja.
# 6575                                                       Travel nerd. Extreme reader. Gamer. Tv advocate. Hipster-friendly troublemaker. Alcohol scholar.
# 6576                  Explorer. General entrepreneur. Infuriatingly humble travel geek. Avid twitter aficionado. Proud tv practitioner. Hardcore web lover.
# 6577                                        Web aficionado. Pop culture lover. Subtly charming coffee guru. Evil bacon evangelist. Organizer. Food scholar.
# 6578                                                        Devoted twitter aficionado. Music enthusiast. Hipster-friendly student. Certified communicator.
# 6579                                 Beer fan. Troublemaker. Twitter evangelist. Tv scholar. Typical travel fanatic. Subtly charming entrepreneur. Creator.
# 6580                                                             Beer fanatic. Coffee maven. Subtly charming music lover. Explorer. Pop culture aficionado.
# 6581                          Professional zombie trailblazer. Extreme internet junkie. Pop culture ninja. Creator. Tv nerd. Beer enthusiast. Twitter guru.
# 6582                                  Travel specialist. Unapologetic tv junkie. Entrepreneur. Wannabe twitter ninja. Unable to type with boxing gloves on.
# 6583                                                 Student. Creator. Professional bacon enthusiast. Proud zombie ninja. Food fan. Gamer. Twitter fanatic.
# 6584                                                     Total troublemaker. Bacon ninja. Hipster-friendly zombie evangelist. Writer. Internet trailblazer.
# 6585                                Friendly student. Zombie fan. Travel maven. Extreme internet scholar. Award-winning explorer. Incurable problem solver.
# 6586                                     Typical creator. Introvert. Pop culture enthusiast. Extreme social media maven. Award-winning gamer. Entrepreneur.
# 6587                                                    Web scholar. Certified food fanatic. Internet expert. Friendly thinker. Unapologetic tv enthusiast.
# 6588                                                                                Hardcore tv geek. Typical music buff. Hipster-friendly beer enthusiast.
# 6589                                                    Pop culture maven. Coffee junkie. Friend of animals everywhere. Student. Professional internet fan.
# 6590                                                          Unapologetic thinker. Certified beer trailblazer. Amateur twitter guru. Hardcore travel nerd.
# 6591                                                       Entrepreneur. Evil alcohol evangelist. Beer maven. Infuriatingly humble travel guru. Music nerd.
# 6592              Typical bacon lover. Professional food evangelist. Pop culture enthusiast. Problem solver. Incurable tv practitioner. Extreme beeraholic.
# 6593                                                            Reader. Music enthusiast. Tv junkie. Creator. Amateur alcohol fanatic. Pop culture fanatic.
# 6594                                           Pop culture lover. Hardcore writer. Alcohol buff. Devoted communicator. Creator. Proud thinker. Travel nerd.
# 6595                                                                     Typical pop culture nerd. Infuriatingly humble internet maven. Alcohol evangelist.
# 6596                                                             Avid web junkie. Lifelong alcohol guru. Hardcore reader. Award-winning twitter evangelist.
# 6597                                                                  Music ninja. Bacon fanatic. Reader. Total communicator. Unapologetic beer specialist.
# 6598                                                                            Communicator. Bacon lover. Award-winning introvert. Amateur internet ninja.
# 6599                                                         Unapologetic tv aficionado. Devoted twitter enthusiast. Typical coffee guru. Falls down a lot.
# 6600                                                                                  food lover. social media fanatic. extraordinarily humble. life lover.
#
#         Movies        TV  Religion     Music    Sports     Books  Politics
# 0     0.555556  0.333333  0.444444  0.111111  0.333333  0.666667  0.777778
# 1     0.777778  1.000000  0.555556  0.111111  1.000000  0.444444  0.000000
# 2     0.111111  0.222222  0.666667  0.555556  0.666667  0.555556  0.444444
# 3     0.555556  0.222222  0.777778  0.888889  0.222222  0.666667  0.666667
# 4     0.666667  0.666667  0.666667  0.444444  0.333333  0.666667  0.333333
# 5     0.000000  0.555556  0.777778  0.555556  1.000000  0.222222  0.000000
# 6     0.555556  0.444444  0.777778  0.555556  0.000000  0.888889  0.444444
# 7     1.000000  0.888889  0.888889  0.222222  0.000000  0.000000  0.555556
# 8     0.888889  0.888889  0.222222  0.666667  0.111111  0.222222  1.000000
# 9     1.000000  0.000000  0.222222  0.222222  0.555556  0.666667  0.888889
# 10    1.000000  0.222222  0.333333  0.444444  0.444444  1.000000  0.444444
# 11    0.000000  0.000000  0.222222  0.222222  0.333333  0.888889  1.000000
# 12    0.111111  0.666667  0.444444  0.444444  0.000000  0.111111  0.333333
# 13    0.222222  0.222222  0.222222  0.111111  0.222222  0.444444  0.777778
# 14    0.000000  0.444444  0.333333  1.000000  0.666667  0.444444  0.555556
# 15    0.666667  1.000000  0.000000  0.333333  0.000000  0.666667  0.222222
# 16    1.000000  0.111111  0.555556  0.111111  0.666667  0.333333  0.111111
# 17    0.111111  0.444444  0.888889  0.111111  0.333333  0.555556  0.333333
# 18    0.222222  1.000000  0.333333  0.666667  0.666667  0.222222  1.000000
# 19    0.666667  0.555556  0.222222  0.444444  0.888889  0.888889  0.555556
# 20    0.888889  0.666667  1.000000  0.666667  0.444444  0.333333  0.111111
# 21    0.666667  0.555556  0.888889  0.555556  0.777778  1.000000  0.888889
# 22    0.222222  0.333333  0.000000  1.000000  0.333333  0.666667  0.111111
# 23    0.000000  0.000000  0.888889  0.333333  0.555556  0.777778  0.444444
# 24    0.888889  1.000000  0.111111  0.444444  0.888889  0.000000  0.777778
# 25    0.000000  0.111111  0.444444  0.111111  0.555556  0.777778  0.333333
# 26    0.111111  1.000000  0.777778  0.555556  0.111111  1.000000  0.111111
# 27    0.444444  0.111111  0.666667  1.000000  0.555556  0.444444  0.333333
# 28    0.111111  0.444444  0.333333  0.333333  0.222222  0.333333  0.222222
# 29    0.444444  0.000000  1.000000  0.222222  0.555556  0.555556  0.888889
# ...        ...       ...       ...       ...       ...       ...       ...
# 6571  0.333333  0.111111  0.777778  0.666667  0.444444  0.666667  0.888889
# 6572  0.777778  0.111111  0.000000  0.222222  1.000000  0.888889  0.333333
# 6573  1.000000  0.111111  0.666667  0.222222  0.222222  0.666667  0.666667
# 6574  0.333333  0.555556  0.777778  0.111111  0.555556  1.000000  0.555556
# 6575  0.111111  0.666667  0.888889  0.888889  0.111111  0.000000  0.111111
# 6576  0.333333  1.000000  0.888889  0.777778  0.888889  1.000000  0.888889
# 6577  0.777778  0.222222  0.666667  0.333333  0.444444  0.222222  0.333333
# 6578  0.888889  0.888889  0.000000  0.888889  0.777778  0.000000  0.666667
# 6579  0.555556  0.888889  0.000000  0.111111  0.444444  0.111111  0.888889
# 6580  0.111111  0.111111  0.000000  0.666667  0.000000  0.555556  0.333333
# 6581  0.444444  0.000000  0.222222  0.222222  0.000000  0.888889  0.111111
# 6582  0.777778  0.777778  1.000000  1.000000  0.888889  0.555556  0.666667
# 6583  0.000000  0.444444  0.888889  0.777778  0.555556  0.444444  1.000000
# 6584  0.444444  0.000000  0.888889  0.777778  0.555556  0.666667  0.777778
# 6585  0.222222  0.222222  0.666667  0.555556  0.444444  0.444444  0.777778
# 6586  0.222222  0.555556  0.111111  0.333333  0.111111  0.111111  0.555556
# 6587  0.222222  0.888889  0.444444  0.555556  0.111111  0.222222  0.222222
# 6588  0.333333  0.222222  0.888889  0.555556  0.222222  0.222222  0.666667
# 6589  1.000000  0.222222  0.333333  0.888889  0.222222  0.777778  0.444444
# 6590  0.555556  0.666667  0.333333  0.111111  0.666667  1.000000  0.444444
# 6591  0.666667  0.777778  0.333333  0.555556  0.666667  0.333333  0.777778
# 6592  0.888889  0.444444  0.111111  0.222222  0.888889  0.333333  0.666667
# 6593  1.000000  0.777778  0.777778  0.666667  0.333333  0.444444  0.444444
# 6594  0.888889  0.444444  0.888889  0.666667  0.333333  0.000000  0.333333
# 6595  0.777778  1.000000  0.000000  0.000000  0.222222  0.222222  0.444444
# 6596  0.444444  0.333333  0.666667  0.333333  0.777778  0.777778  0.222222
# 6597  0.111111  0.444444  0.000000  0.444444  1.000000  0.222222  0.555556
# 6598  0.666667  0.222222  0.000000  0.333333  0.888889  1.000000  0.111111
# 6599  0.222222  0.111111  0.888889  0.777778  0.000000  0.555556  0.555556
# 6600  0.444444  1.000000  0.333333  0.666667  0.666667  0.000000  0.333333
#
# [6601 rows x 8 columns]

# %% [markdown]
# ### Vectorizing

# %%
# Instantiating the Vectorizer
vectorizer = CountVectorizer()

# Fitting the vectorizer to the Bios
x = vectorizer.fit_transform(df['Bios'])

# Creating a new DF that contains the vectorized words
df_wrds = pd.DataFrame(x.toarray(), columns=vectorizer.get_feature_names())

# Concating the words DF with the original DF
new_df = pd.concat([df, df_wrds], axis=1)

# Dropping the Bios because it is no longer needed in place of vectorization
new_df.drop('Bios', axis=1, inplace=True)

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA

# Instantiating PCA
pca = PCA()

# Fitting and Transforming the DF
df_pca = pca.fit_transform(new_df)

# Finding the exact number of features that explain at least 99% of the variance in the dataset
total_explained_variance = pca.explained_variance_ratio_.cumsum()
n_over_99 = len(total_explained_variance[total_explained_variance>=.99])
n_to_reach_99 = new_df.shape[1] - n_over_99

# Reducing the dataset to the number of features determined before
pca = PCA(n_components=n_to_reach_99)

# Fitting and transforming the dataset to the stated number of features
df_pca = pca.fit_transform(new_df)

# Seeing the variance ratio that still remains after the dataset has been reduced
pca.explained_variance_ratio_.cumsum()[-1]
# Out:
# 0.9898433044921403

# %% [markdown]
# ### Performing Hierarchical Agglomerative Clustering
# - First finding the optimum number of clusters

# %%
# Setting the amount of clusters to test out
cluster_cnt = [i for i in range(2, 20, 1)]

# Establishing empty lists to store the scores for the evaluation metrics
ch_scores = []

s_scores = []

db_scores = []

# Looping through different iterations for the number of clusters
for i in tqdm(cluster_cnt):
    
    # Clustering with different number of clusters
    hac = AgglomerativeClustering(n_clusters=i)
    
    hac.fit(df_pca)
    
    cluster_assignments = hac.labels_
    
    # Appending the scores to the empty lists
    ch_scores.append(calinski_harabaz_score(df_pca, cluster_assignments))
    
    s_scores.append(silhouette_score(df_pca, cluster_assignments))
    
    db_scores.append(davies_bouldin_score(df_pca, cluster_assignments))
# Out:
# HBox(children=(IntProgress(value=0, max=18), HTML(value='')))
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances

# %% [markdown]
# ### Helper Function to Evaluate the Clusters

# %%
def cluster_eval(y, x):
    """
    Prints the scores of a set evaluation metric. Prints out the max and min values of the evaluation scores.
    """
    
    # Creating a DataFrame for returning the max and min scores for each cluster
    df = pd.DataFrame(columns=['Cluster Score'], index=[i for i in range(2, len(y)+2)])
    df['Cluster Score'] = y
    
    print('Max Value:\nCluster #', df[df['Cluster Score']==df['Cluster Score'].max()])
    print('\nMin Value:\nCluster #', df[df['Cluster Score']==df['Cluster Score'].min()])

# %% [markdown]
# ### Evaluation of Clusters

# %%
print("The Calinski-Harabasz Score (find max score):")
cluster_eval(ch_scores, cluster_cnt)

print("\nThe Silhouette Coefficient Score (find max score):")
cluster_eval(s_scores, cluster_cnt)

print("\nThe Davies-Bouldin Score (find minimum score):")
cluster_eval(db_scores, cluster_cnt)
# Out:
# The Calinski-Harabasz Score (find highest score):
# Max Value:
# Cluster #    Cluster Score
# 2     120.008244
#
# Min Value:
# Cluster #     Cluster Score
# 19      57.657188
#
# The Silhouette Coefficient Score (find highest score):
# Max Value:
# Cluster #     Cluster Score
# 12        0.03048
#
# Min Value:
# Cluster #    Cluster Score
# 2        0.01585
#
# The Davies-Bouldin Score (find lowest score):
# Max Value:
# Cluster #     Cluster Score
# 19       5.449615
#
# Min Value:
# Cluster #     Cluster Score
# 12       4.006027

# %% [markdown]
# ### Running HAC
# Again but with the optimum cluster count

# %%
# Instantiating HAC
hac = AgglomerativeClustering(n_clusters=12)

# Fitting
hac.fit(df_pca)

# Getting cluster assignments
cluster_assignments = hac.labels_

# Unscaling the categories then replacing the scaled values
df = df[['Bios']].join(pd.DataFrame(scaler.inverse_transform(df.drop('Bios', axis=1)), columns=df.columns[1:], index=df.index))

# Assigning the clusters to each profile
df['Cluster #'] = cluster_assignments

# %% [markdown]
# ### Finding the Exact Cluster for our New Profile

# %%
# Getting the Cluster # for the new profile
profile_cluster = df.loc[new_profile.index]['Cluster #'].values[0]

# Using the Cluster # to narrow down the DF
profile_df = df[df['Cluster #']==profile_cluster].drop('Cluster #', axis=1)
# Out:
#                                                                                                                                                                 Bios  \
# 6                                                                        Typical thinker. Amateur explorer. Reader. Extreme student. Tv fanatic. Social media ninja.
# 14                                                         Travel buff. Student. Alcohol trailblazer. Passionate social media ninja. Entrepreneur. Incurable writer.
# 17                                                     Beer practitioner. Coffee expert. Tv guru. Social media junkie. Bacon enthusiast. General student. Food nerd.
# 46                                                                Explorer. Social media buff. Evil bacon nerd. Friendly zombie evangelist. Typical travel advocate.
# 52                                                                       Problem solver. Internet evangelist. Devoted social media fanatic. Passionate twitter geek.
# 74                                                                                Hardcore beer practitioner. Typical bacon evangelist. Certified social media buff.
# 85                                            Freelance social media nerd. Internet ninja. Introvert. Beer evangelist. Alcohol enthusiast. Bacon geek. Troublemaker.
# 88                                                          Typical bacon aficionado. Internet guru. Food lover. Music enthusiast. Twitter geek. Social media ninja.
# 89                                              Introvert. Freelance music expert. Devoted social media advocate. Evil reader. Zombie fanatic. Professional analyst.
# 97                                                                   Thinker. Lifelong travelaholic. Alcohol enthusiast. Incurable social media lover. Communicator.
# 111             Social media fanatic. Zombie buff. Food geek. Lifelong entrepreneur. Evil bacon maven. Travel fan. Writer. Communicator. Friendly coffee enthusiast.
# 113                          Social media junkie. Hipster-friendly internet specialist. Avid food enthusiast. Bacon advocate. Musicaholic. Alcohol fan. Zombie nerd.
# 119                                                                            Social media buff. Professional travel aficionado. Friendly analyst. Alcohol fanatic.
# 122                                 Internet enthusiast. Bacon fan. Hipster-friendly music maven. Certified social media nerd. Alcohol evangelist. Future teen idol.
# 126                                    Incurable beer aficionado. Social media ninja. Food fanatic. Tv practitioner. Total web junkie. Hipster-friendly music lover.
# 129                          Incurable social media fanatic. Analyst. Introvert. Gamer. Unapologetic writer. General tv expert. Zombie lover. Total food evangelist.
# 156                                                                          Extreme web maven. Twitter trailblazer. Passionate social media fanatic. Beer advocate.
# 166                                                 Organizer. Hipster-friendly twitter evangelist. Social media junkie. Pop culture expert. Introvert. Coffee buff.
# 169                                                                   Food nerd. Coffee buff. Tv aficionado. Amateur explorer. Web fanatic. Social media enthusiast.
# 171                                                                    Evil zombie enthusiast. Troublemaker. Professional social media scholar. Internet aficionado.
# 181                                                           Devoted organizer. General music aficionado. Social media enthusiast. Food nerd. Freelance beer maven.
# 185                                                 Social media buff. Evil introvert. Tv practitioner. Incurable twitter nerd. Typical food fanatic. Music fanatic.
# 186                             Hipster-friendly entrepreneur. Passionate travel maven. Freelance social media fanatic. Bacon evangelist. Reader. Proud web fanatic.
# 191                                                                   Social media fanatic. Hardcore web aficionado. Evil internet advocate. Incurable entrepreneur.
# 192                                         Alcohol buff. Professional social media junkie. Avid zombie lover. Internet expert. Analyst. Friendly travel enthusiast.
# 195                                                                                        Amateur zombie buff. Explorer. Avid writer. Passionate social media geek.
# 198                                                 Twitter fanatic. Devoted alcohol guru. Travel lover. Beer evangelist. Passionate social media fan. Avid analyst.
# 203                                                                                 Travel nerd. Zombie fan. Web evangelist. Social media scholar. Internet fanatic.
# 212                                                                 Tv fanatic. Writer. Lifelong social media advocate. Certified coffee ninja. Passionate explorer.
# 217                                         Alcohol buff. Professional social media junkie. Avid zombie lover. Internet expert. Analyst. Friendly travel enthusiast.
# ...                                                                                                                                                              ...
# 6344                                                                 Friendly thinker. Hardcore travel guru. Passionate social media expert. Freelance entrepreneur.
# 6369                                                                                    Creator. Proud student. Devoted social media advocate. Wannabe entrepreneur.
# 6371                                                                    Bacon aficionado. Alcohol buff. Zombieaholic. Total social media fanatic. General beer guru.
# 6393                                                         Social media fan. Coffee nerd. Unapologetic food aficionado. Troublemaker. Wannabe twitter trailblazer.
# 6394                     General travel nerd. Avid twitter guru. Hipster-friendly social media junkie. Incurable coffee practitioner. Introvert. Pop culture expert.
# 6401                         Internet guru. Hardcore writer. Freelance bacon expert. Web ninja. Passionate social media nerd. General gamer. Lifelong coffee junkie.
# 6407                                                                 Typical tv aficionado. Bacon fanatic. Social media geek. Extreme travel guru. Beer trailblazer.
# 6408                                                             Hipster-friendly social mediaholic. Creator. Proud bacon nerd. Unapologetic pop culture enthusiast.
# 6414                                                              Professional coffee specialist. Social media trailblazer. Passionate reader. Extreme travelaholic.
# 6415                                                                       Student. Zombie advocate. Analyst. Web buff. Social media practitioner. Music evangelist.
# 6416                             Certified internet expert. Coffeeaholic. Professional social media fanatic. Amateur alcohol enthusiast. Friendly zombie aficionado.
# 6418                                                               Social media geek. Avid beer ninja. Reader. Tv scholar. Alcohol trailblazer. Explorer. Organizer.
# 6421                                                             Amateur thinker. Web maven. Certified social media scholar. Incurable music junkie. Zombie fanatic.
# 6445                                                                           Social media buff. Professional travel aficionado. Friendly analyst. Alcohol fanatic.
# 6456                                              Explorer. Zombie advocate. Lifelong analyst. Social media aficionado. Travel buff. Wannabe thinker. Bacon scholar.
# 6457                                                                              Creator. Social media aficionado. Tv buff. Total explorer. Certified zombie maven.
# 6459                                                      Infuriatingly humble bacon nerd. Reader. Internet geek. Wannabe analyst. Devoted explorer. Web enthusiast.
# 6463  Certified music scholar. Coffee geek. Subtly charming food lover. Professional social media guru. Hardcore beer fan. Internet nerd. Thinker. Bacon specialist.
# 6474                                                                                Wannabe baconaholic. Music evangelist. Hardcore alcohol ninja. Social media fan.
# 6488                                                Wannabe social media enthusiast. Certified explorer. Professional web nerd. Friendly travel expert. Beer junkie.
# 6507                                                                       Amateur social media nerd. Web enthusiast. Avid zombie geek. Certified pop cultureaholic.
# 6515                      Bacon nerd. Certified twitter specialist. Social media fanatic. Friendly internet aficionado. Alcohol evangelist. Thinker. Proud explorer.
# 6524                                                 Tv guru. General food practitioner. Beer expert. Zombie maven. Total social media geek. Thinker. Music scholar.
# 6527                                                                                  Reader. Freelance analyst. Social media fan. Wannabe food ninja. Twitter geek.
# 6533                                                                             Social media fan. Food practitioner. Pop cultureaholic. Hipster-friendly introvert.
# 6542                                                                   Explorer. Evil internet buff. Lifelong social media maven. Troublemaker. Incurable organizer.
# 6546                           Certified analyst. Social media fanatic. Tv trailblazer. Passionate food aficionado. Music fanatic. Zombie junkie. Beer practitioner.
# 6559                                                                 Hipster-friendly analyst. Alcohol specialist. Total communicator. General social media fanatic.
# 6566                                                                   Professional social media aficionado. Alcohol fanatic. Total thinker. Incurable communicator.
# 6600                                                                                           food lover. social media fanatic. extraordinarily humble. life lover.
#
#       Movies   TV  Religion  Music  Sports  Books  Politics
# 6        5.0  4.0       7.0    5.0     0.0    8.0       4.0
# 14       0.0  4.0       3.0    9.0     6.0    4.0       5.0
# 17       1.0  4.0       8.0    1.0     3.0    5.0       3.0
# 46       4.0  9.0       7.0    6.0     0.0    6.0       2.0
# 52       3.0  6.0       8.0    9.0     3.0    1.0       3.0
# 74       3.0  7.0       8.0    2.0     1.0    0.0       7.0
# 85       2.0  8.0       2.0    5.0     4.0    9.0       1.0
# 88       8.0  0.0       8.0    1.0     4.0    3.0       5.0
# 89       4.0  6.0       6.0    3.0     4.0    0.0       6.0
# 97       5.0  8.0       2.0    8.0     0.0    9.0       8.0
# 111      7.0  8.0       4.0    1.0     5.0    9.0       5.0
# 113      7.0  9.0       3.0    3.0     3.0    0.0       6.0
# 119      7.0  6.0       3.0    5.0     9.0    0.0       2.0
# 122      7.0  6.0       2.0    3.0     8.0    3.0       2.0
# 126      5.0  3.0       5.0    9.0     7.0    0.0       0.0
# 129      4.0  1.0       4.0    5.0     4.0    8.0       3.0
# 156      3.0  5.0       2.0    2.0     1.0    0.0       7.0
# 166      7.0  3.0       9.0    8.0     5.0    7.0       4.0
# 169      8.0  8.0       5.0    5.0     3.0    1.0       9.0
# 171      6.0  4.0       8.0    0.0     8.0    1.0       5.0
# 181      1.0  5.0       7.0    8.0     5.0    7.0       0.0
# 185      5.0  5.0       0.0    0.0     7.0    5.0       9.0
# 186      9.0  5.0       7.0    4.0     7.0    5.0       7.0
# 191      2.0  6.0       5.0    6.0     9.0    6.0       0.0
# 192      9.0  3.0       2.0    1.0     6.0    4.0       8.0
# 195      9.0  5.0       8.0    7.0     4.0    5.0       1.0
# 198      9.0  2.0       7.0    0.0     1.0    6.0       7.0
# 203      5.0  4.0       2.0    2.0     7.0    7.0       4.0
# 212      3.0  6.0       6.0    1.0     3.0    7.0       3.0
# 217      5.0  1.0       1.0    2.0     3.0    6.0       4.0
# ...      ...  ...       ...    ...     ...    ...       ...
# 6344     2.0  0.0       9.0    8.0     8.0    8.0       1.0
# 6369     9.0  5.0       2.0    0.0     8.0    3.0       6.0
# 6371     3.0  9.0       3.0    8.0     1.0    4.0       8.0
# 6393     1.0  9.0       1.0    7.0     7.0    4.0       5.0
# 6394     5.0  0.0       9.0    9.0     7.0    4.0       4.0
# 6401     4.0  5.0       9.0    5.0     4.0    3.0       2.0
# 6407     5.0  1.0       1.0    1.0     6.0    0.0       1.0
# 6408     1.0  4.0       9.0    0.0     4.0    5.0       3.0
# 6414     3.0  6.0       8.0    0.0     2.0    2.0       8.0
# 6415     8.0  4.0       0.0    9.0     6.0    3.0       1.0
# 6416     2.0  4.0       6.0    4.0     8.0    1.0       3.0
# 6418     1.0  8.0       4.0    5.0     3.0    0.0       5.0
# 6421     1.0  5.0       0.0    3.0     6.0    2.0       7.0
# 6445     6.0  8.0       2.0    7.0     9.0    8.0       6.0
# 6456     0.0  5.0       2.0    4.0     8.0    3.0       8.0
# 6457     3.0  8.0       6.0    5.0     6.0    3.0       6.0
# 6459     5.0  5.0       1.0    4.0     4.0    1.0       2.0
# 6463     7.0  6.0       3.0    2.0     2.0    7.0       1.0
# 6474     4.0  1.0       6.0    3.0     8.0    7.0       1.0
# 6488     9.0  1.0       9.0    5.0     9.0    5.0       9.0
# 6507     8.0  2.0       3.0    8.0     1.0    1.0       4.0
# 6515     0.0  0.0       6.0    9.0     8.0    9.0       6.0
# 6524     2.0  2.0       8.0    5.0     1.0    1.0       3.0
# 6527     2.0  2.0       7.0    2.0     3.0    4.0       1.0
# 6533     7.0  4.0       0.0    6.0     0.0    2.0       4.0
# 6542     8.0  0.0       4.0    9.0     7.0    7.0       8.0
# 6546     9.0  6.0       4.0    1.0     7.0    1.0       3.0
# 6559     7.0  7.0       0.0    2.0     6.0    3.0       2.0
# 6566     4.0  1.0       6.0    0.0     1.0    4.0       0.0
# 6600     4.0  9.0       3.0    6.0     6.0    0.0       3.0
#
# [766 rows x 8 columns]

# %% [markdown]
# ### Vectorizing the Selected Cluster

# %%
# Fitting the vectorizer to the Bios
cluster_x = vectorizer.fit_transform(profile_df['Bios'])

# Creating a new DF that contains the vectorized words
cluster_v = pd.DataFrame(cluster_x.toarray(), index=profile_df.index, columns=vectorizer.get_feature_names())

# Joining the Vectorized DF to the previous DF
profile_df = profile_df.join(cluster_v).drop('Bios', axis=1)

# %% [markdown]
# ### Finding Correlation for Top 10 Similar Profiles to the New Profile

# %%
# Trasnposing the DF so that we are correlating with the index(users) and finding the correlation
corr = profile_df.T.corr()

# Finding the Top 10 similar or correlated users to the new user
user_n = new_profile.index[0]

# Creating a DF with the Top 10 most similar profiles
top_10_sim = corr[[user_n]].sort_values(by=[user_n],axis=0, ascending=False)[1:11]

# %% [markdown]
# ### The Top 10 Profiles most likely to Match with the New Profile
# (Sorted by descending similarity)

# %%
raw_df.loc[top_10_sim.index]
# Out:
#                                                                                                                                                  Bios  \
# 4703  Devoted reader. Bacon aficionado. Lifelong internet specialist. Food fan. Extreme twitter buff. Friendly coffee enthusiast. Social media lover.
# 4931                                                                Coffee junkie. Social media ninja. Typical twitter specialist. Tvaholic. Student.
# 4362                               Total bacon fanatic. Professional troublemaker. Proud pop culture lover. Hipster-friendly social media evangelist.
# 2718                                  General beer advocate. Hipster-friendly introvert. Social media nerd. Gamer. Alcohol geek. Professional writer.
# 367                                     Organizer. Professional alcoholaholic. Hipster-friendly social media fanatic. Total zombie evangelist. Gamer.
# 4553                                                Alcohol trailblazer. Passionate creator. Typical social media junkie. Avid zombie fanatic. Gamer.
# 3711                                    Internet lover. General social media advocate. Hardcore music maven. Web buff. Devoted tv fan. Zombie expert.
# 5480                                                           Internet expert. Social media scholar. Hipster-friendly zombie maven. Amateur tv buff.
# 4814                                           Entrepreneur. Certified foodaholic. Unapologetic thinker. Incurable travel guru. Wannabe alcohol buff.
# 1823                                                    Devoted reader. Alcoholaholic. Coffee nerd. Evil organizer. Analyst. Passionate troublemaker.
#
#       Movies  TV  Religion  Music  Sports  Books  Politics
# 4703       6   9         1      9       9      1         7
# 4931       6   8         1      5       5      0         1
# 4362       9   9         3      9       7      2         1
# 2718       2   9         1      6       8      1         2
# 367        4   9         1      9       8      0         0
# 4553       3   8         5      5       9      2         2
# 3711       6   8         5      6       8      0         8
# 5480       5   9         3      9       7      5         5
# 4814       4   9         3      6       7      4         6
# 1823       5   8         5      9       9      0         9

# %% [markdown]
# ## Classification of the New Profile

# %% [markdown]
# ### Importing the Different Classification Models

# %%
# Importing the 10 models
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

## Preventing error from occuring: XGBoost causes kernel to die.
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
from xgboost import XGBClassifier

# %% [markdown]
# ### Splitting the Data

# %%
X = cluster_df.drop(["Cluster #"], 1)
y = cluster_df['Cluster #']

# Train, test, split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ### Creating Model Pipelines

# %%
# Adaboost
pipe_ada = Pipeline([('scale', MinMaxScaler()), ('clf', AdaBoostClassifier())])

# Gradient Boost
pipe_gb  = Pipeline([('scale', MinMaxScaler()), ('clf', GradientBoostingClassifier())])

# Random Forest
pipe_rf  = Pipeline([('scale', MinMaxScaler()), ('clf', RandomForestClassifier())])

# Decision Tree
pipe_dt  = Pipeline([('scale', MinMaxScaler()), ('clf', DecisionTreeClassifier())])

# Dummy (Baseline)
pipe_dum = Pipeline([('scale', MinMaxScaler()), ('clf', DummyClassifier())])

# K Nearest Neighbors
pipe_knn = Pipeline([('scale', MinMaxScaler()), ('clf', KNeighborsClassifier())])

# Logistic Regression
pipe_lr  = Pipeline([('scale', MinMaxScaler()), ('clf', LogisticRegression())])

# Naive Bayes
pipe_nb  = Pipeline([('scale', MinMaxScaler()), ('clf', GaussianNB())])

# Support Vector Machine
pipe_svm = Pipeline([('scale', MinMaxScaler()), ('clf', SVC())])

# XGBoost
pipe_xgb = Pipeline([('scale', MinMaxScaler()), ('clf', XGBClassifier())])

# Creating a list for pipelines and model names
pipelines = [pipe_ada, pipe_gb, pipe_rf, pipe_dt, pipe_dum, 
             pipe_knn, pipe_lr, pipe_nb, pipe_svm, pipe_xgb]

models = ['Adaboost', 
          'GradientBoost', 
          'RandomForest', 
          'DecisionTree', 
          'Dummy(Baseline)', 
          'KNN', 
          'LogisticRegression',
          'NaiveBayes',
          'SupportVectorMachine',
          'XGBoost']

# Zipping the the strings and pipelines together and creating a dictionary
model_pipelines = dict(zip(models, pipelines))
